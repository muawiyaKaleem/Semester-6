# %% [markdown]
# ## Question # 01

# %%
import pandas as pd
import numpy as np
import math

nearest_labels = []
mydict = {}

def findeuclidean_distance(value,x1,y1):
    if(value):
        x2,y2 = value
        return math.sqrt((x2-x1)**2+(y2-y1)**2)
    
class KNN:
    def __init__(self) -> None:
        self.k = 3

    def predict(self,X_test):
        x1,y1 = X_test
        zipped = zip(data["Smoke"],data["Lungs Capacity"])
        j=0
        for i in zipped:
            mydict[j] = findeuclidean_distance(i,x1,y1)
            j = j+1

    def find_ylabels(self):
        nearest_indices = sorted(mydict, key=mydict.get)[:self.k]
        for i in nearest_indices:
            if i in data.index:
                nearest_labels.append(data['Cancer'][i])
        predicted_label = max(nearest_labels, key=nearest_labels.count)
        return predicted_label

data = pd.DataFrame(pd.read_csv("dataset.csv"))
X_test = np.array([10,2])

knn = KNN()
knn.predict(X_test)

label = knn.find_ylabels()
if (label):
    print(f"For this data {X_test}, Cancer is: Positive")
else:
    print(f"For this data {X_test}, Cancer is: Negitive")
# Out:
# For this data [10  2], Cancer is: Positive

# %% [markdown]
# ## Question # 02

# %%
import pandas as pd 
import numpy as np 
import math
from sklearn.model_selection import train_test_split
from sklearn.neighbors import  KNeighborsRegressor
# from sklearn.metrics import confusion_matrix              # for classification
# from sklearn.preprocessing import StandardScaler
# from sklearn.metrics import f1_score
# from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt

data = pd.DataFrame(pd.read_csv("fruit_data_with_colors _1_.csv"))
columns = ["mass","height"]
for column in columns:
    mean = int(data[column].mean())
    data[column] = data[column].replace(np.NaN,mean)

X = data.iloc[:,[0]+list(range(3,6))]
Y = data.iloc[:,6]

X_train,X_test,Y_train,Y_test=train_test_split(X,Y, random_state=0,test_size=0.2)

regressor = KNeighborsRegressor(n_neighbors=3,p=2,metric="euclidean")
regressor.fit(X_train,Y_train)
predictions = regressor.predict(X_test)

mar = mean_absolute_error(Y_test,predictions)
plt.scatter(Y_test, predictions)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs. Predicted Values")
plt.show()
